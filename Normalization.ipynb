     6.990E-03  0.0028e-03   1.2830E+01    4.0414E-01
     5.990E-03  0.0026e-03   1.3480E+01    3.8553E-01
     4.992E-03  0.0024e-03   1.2630E+01    5.7972E-01
'''

# %%
kobzev = ''' 46.0E-03  1.2E-03           25.93       0.52
    48.0E-03  1.2E-03           25.96       0.52
    52.0E-03  1.3E-03           25.76       0.52
    56.0E-03  1.4E-03           25.28       0.51
    60.0E-03  1.5E-03           24.77       0.50
    64.0E-03  1.3E-03           23.66       0.47
    66.0E-03  1.3E-03           22.85       0.46
    68.0E-03  1.4E-03           21.89       0.44
    72.0E-03  1.4E-03           19.98       0.40
    76.0E-03  1.5E-03           18.14       0.36
    80.0E-03  1.6E-03           16.53       0.33
    84.0E-03  1.7E-03           15.01       0.30
    88.0E-03  1.8E-03           13.65       0.27
    92.0E-03  1.8E-03           12.50       0.25
    96.0E-03  1.9E-03           11.41       0.23
   100.0E-03  2.0E-03           10.45       0.21
   104.0E-03  2.1E-03            9.59       0.19
   108.0E-03  2.2E-03            8.76       0.18
   112.0E-03  2.2E-03            7.98       0.16
   116.0E-03  2.3E-03            7.28       0.15
   120.0E-03  2.4E-03            6.65       0.13
   124.0E-03  2.5E-03            6.08       0.12
   128.0E-03  2.6E-03            5.61       0.11
   132.0E-03  2.6E-03            5.23       0.10
   136.0E-03  2.7E-03            4.89       0.10
   140.0E-03  2.8E-03            4.60       0.09
   144.0E-03  2.9E-03            4.32       0.09
   148.0E-03  3.0E-03            4.11       0.08
   152.0E-03  3.0E-03            3.88       0.08
   156.0E-03  3.1E-03            3.69       0.07
   160.0E-03  3.2E-03            3.50       0.07
   164.0E-03  3.3E-03            3.32       0.08
   168.0E-03  3.4E-03            3.15       0.08
   176.0E-03  3.5E-03            2.84       0.07
   184.0E-03  3.7E-03            2.62       0.07
   192.0E-03  3.8E-03            2.42       0.06
   200.0E-03  4.0E-03            2.26       0.06
   208.0E-03  4.2E-03            2.13       0.05
   216.0E-03  4.3E-03            2.00       0.05
   224.0E-03  4.5E-03            1.89       0.05
   232.0E-03  4.6E-03            1.79       0.04
   240.0E-03  4.8E-03            1.69       0.04
   248.2E-03  5.0E-03            1.60       0.04
   256.2E-03  5.1E-03            1.51       0.04
   264.3E-03  5.3E-03            1.44       0.04
   
'''

# %%
# separate them all into components: 
#function for sepearating data 
def separate_data(data):
    lines = data.strip().split('\n')
    COM = []
    COMerror = []
    sfactor = []
    sfactorerror = []

    for line in lines:
        parts = line.split()
        COM.append(float(parts[0]))
        COMerror.append(float(parts[1]))
        sfactor.append(float(parts[2]))
        sfactorerror.append(float(parts[3]))

    return COM, COMerror, sfactor, sfactorerror

# %%
arnoldCOM, arnoldCOMerror, arnoldsfactor, arnoldsfactorerror = separate_data(arnold)
brownCOM, brownCOMerror, brownsfactor, brownsfactorerror = separate_data(brown)
connerCOM, connerCOMerror, connersfactor, connersfactorerror = separate_data(conner)
jarmieCOM, jarmieCOMerror, jarmiesfactor, jarmiesfactorerror = separate_data(jarmie)
kobzevCOM, kobzevCOMerror, kobzevsfactor, kobzevsfactorerror = separate_data(kobzev)

# %%
#plotting before normalizing 
plt.scatter(brownCOM, brownsfactor, color='red', label='Brown')
plt.scatter(arnoldCOM, arnoldsfactor, color='orange', label='Arnold')
plt.scatter(connerCOM, connersfactor, color='green', label='Conner')
plt.scatter(jarmieCOM, jarmiesfactor, color='blue', label='Jarmie')
plt.scatter(kobzevCOM, kobzevsfactor, color='purple', label='Kobzev')

# Add labels and legend
plt.xlabel("COM Energy (MeV)")
plt.ylabel("S Factor (MeV.barns)")
plt.title('Combined Scatter Plot - not normalized')
plt.legend()

# Show plot
plt.show()

# %%
#normalization with fig 6 
#conner normalization = 0.995
for i in range(len(connersfactor)):
    connersfactor[i] = connersfactor[i] / 0.99
    
#arnold normalization = 0.975
for i in range(len(arnoldsfactor)):
    arnoldsfactor[i] = arnoldsfactor[i] / 1.01
    
#Kobzev normalization = 0.983
for i in range(len(kobzevsfactor)):
    kobzevsfactor[i] = kobzevsfactor[i] / 0.98
    
#Jarmie normalization = 1.01
for i in range(len(jarmiesfactor)):
    jarmiesfactor[i] = jarmiesfactor[i] / 0.95
    

#Brown = 0.99
for i in range(len(brownsfactor)):
    brownsfactor[i] = brownsfactor[i] / 0.975

# %%
#plotting before normalizing 
plt.scatter(brownCOM, brownsfactor, color='red', label='Brown')
plt.scatter(arnoldCOM, arnoldsfactor, color='orange', label='Arnold')
plt.scatter(connerCOM, connersfactor, color='green', label='Conner')
plt.scatter(jarmieCOM, jarmiesfactor, color='blue', label='Jarmie')
plt.scatter(kobzevCOM, kobzevsfactor, color='purple', label='Kobzev')

# Add labels and legend
plt.xlabel("COM Energy (MeV)")
plt.ylabel("S Factor (MeV.barns)")
plt.title('Combined Scatter Plot - normalized by fig 6')
plt.legend()

# Show plot
plt.show()

# %%
#normalized according to fig 19
#conner normalization = 1.003
for i in range(len(connersfactor)):
    connersfactor[i] = connersfactor[i] / 0.997
    
#arnold normalization = 0.983
for i in range(len(arnoldsfactor)):
    arnoldsfactor[i] = arnoldsfactor[i] / 1.015
    
#Kobzev normalization = GTFO
#for i in range(len(kobzevsfactor)):
    #kobzevsfactor[i] = kobzevsfactor[i] / 
    
#Jarmie normalization = 1.015
for i in range(len(jarmiesfactor)):
    jarmiesfactor[i] = jarmiesfactor[i] / 1.003
    

#Brown = 0.997
for i in range(len(brownsfactor)):
    brownsfactor[i] = brownsfactor[i] / 0.983

# %%
#plotting before normalizing 
plt.scatter(brownCOM, brownsfactor, color='red', label='Brown')
plt.scatter(arnoldCOM, arnoldsfactor, color='orange', label='Arnold')
plt.scatter(connerCOM, connersfactor, color='green', label='Conner')
plt.scatter(jarmieCOM, jarmiesfactor, color='blue', label='Jarmie')
#plt.scatter(kobzevCOM, kobzevsfactor, color='purple', label='Kobzev')

# Add labels and legend
plt.xlabel("COM Energy (MeV)")
plt.ylabel("S Factor (MeV.barns)")
plt.title('Combined Scatter Plot - normalized by fig 19')
plt.legend()

# Show plot
plt.show()

# %%
print(brownCOM, brownsfactor)
#  10.47609325 10.62862707 10.58545873 10.58470131 10.64895991 10.72147041
#  10.66330452 10.6307675  10.55063891 10.55969504 10.60903704 10.63515807
#  10.82086872 10.47823317 10.85899564 10.55913551 10.50657055 10.49790142
#  10.55139599 10.75961142 10.69164654 10.65542284 10.70608937 10.79233129
#  10.65947632 10.5680064  10.3944885  10.54678713 10.52759    10.65565072
#  10.62278173 10.62715514 10.7528614  10.75315825 10.54216645 10.54827978
#  10.62994301 10.64616751 10.51822808 10.66985316 10.6798322  10.58995055
#  10.55254929 10.53318361 10.40703943 10.68119768 10.64953071 10.69278869
#  10.38559091 10.74071521 10.57473826 10.92393467 10.58826243 10.83710122
# ...

# %%
#sampling each point:
mu6, sigma6 = 2.51574E+00  , 0.03  # mean and standard deviation
s6 = np.random.normal(mu6, sigma6, 100)
print(s6)
# Out:
# [2.50348066 2.51928285 2.47043304 2.51452019 2.51996166 2.56429295
#  2.52142049 2.46460299 2.51265785 2.50043202 2.51131338 2.55424028
#  2.48272811 2.58411303 2.55238973 2.53494824 2.54713006 2.51163512
#  2.56247344 2.53516701 2.48014291 2.50430966 2.50784616 2.52493221
#  2.45427591 2.50645523 2.51149191 2.46609049 2.50026746 2.50684777
#  2.4951555  2.52686918 2.45030459 2.52405883 2.49418912 2.53543878
#  2.55925329 2.55619299 2.49586708 2.53014595 2.53736481 2.47336551
#  2.56829409 2.52342079 2.59744209 2.51771993 2.55019679 2.51772979
#  2.56443779 2.51930218 2.45222702 2.52097807 2.53724697 2.50888602
#  2.50564727 2.52333915 2.4840254  2.52249619 2.54157511 2.46251996
#  2.50775979 2.52039505 2.53221049 2.46651869 2.5692601  2.49545191
#  2.45499213 2.52218027 2.50837114 2.50742013 2.47960263 2.56588323
#  2.50784864 2.55850608 2.53502304 2.49210397 2.52616791 2.50059153
#  2.53485808 2.56451625 2.52305573 2.50073958 2.53483061 2.5399895
# ...

# %%
s1=np.array(s1)
s2=np.array(s2)
s3=np.array(s3)
s4=np.array(s4)
s5=np.array(s5)
s6=np.array(s6)
arrays = [s1,s2,s3,s4,s5,s6]

# %%
# Create 100 new arrays with 6 elements each and assign variable names
y_train_arrays = {}
for i in range(100):
    new_array = [array[i % len(array)][0] if isinstance(array[i % len(array)], list) else array[i % len(array)] for array in arrays]
    y_train_arrays[f"y_train_{i+1}"] = new_array

# Display the new arrays
for name, arr in y_train_arrays.items():
    print(f"{name}: {arr}")
# Out:
# y_train_1: [13.87697818821428, 25.298072410990066, 28.016792823663845, 22.713957914250713, 10.592963161374113, 2.503480658031731]
# y_train_2: [12.698709825012779, 25.720906014054012, 28.013938842463336, 22.73677563854865, 10.648422732289719, 2.5192828454888603]
# y_train_3: [13.552951396835626, 25.44687138574295, 27.928023310647184, 22.691410195338047, 10.586441590139254, 2.4704330404551524]
# y_train_4: [13.232397615140929, 26.02861138902723, 28.063452295833223, 22.725130732042523, 10.735448507667158, 2.5145201885951347]
# y_train_5: [13.409975377368303, 25.76995837431387, 28.113928798733326, 22.72942977811078, 10.69079831476272, 2.519961662124005]
# y_train_6: [13.71667163169844, 26.09261807701592, 28.204041842954894, 22.726366087931147, 10.565099327412781, 2.5642929498772054]
# y_train_7: [13.480120121386589, 25.653475099787112, 27.916506505562886, 22.685542656071945, 10.73644806860068, 2.5214204925373487]
# ...

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF

# %%
# Accessing a variable from the dictionary
variable_name = "y_train_1"  # Example variable name
array1 = y_train_arrays[variable_name]

# Displaying the array
print(array1)

# Accessing a variable from the dictionary
variable_name = "y_train_10"  # Example variable name
array10 = y_train_arrays[variable_name]

# Displaying the array
print(array10)

# Accessing a variable from the dictionary
variable_name = "y_train_20"  # Example variable name
array20 = y_train_arrays[variable_name]

# Displaying the array
print(array20)

# Accessing a variable from the dictionary
variable_name = "y_train_30"  # Example variable name
array30 = y_train_arrays[variable_name]

# Displaying the array
print(array30)

# Accessing a variable from the dictionary
variable_name = "y_train_40"  # Example variable name
array40 = y_train_arrays[variable_name]

# Displaying the array
print(array40)

# Accessing a variable from the dictionary
variable_name = "y_train_50"  # Example variable name
array50 = y_train_arrays[variable_name]

# Displaying the array
print(array50)

# Accessing a variable from the dictionary
variable_name = "y_train_60"  # Example variable name
array60 = y_train_arrays[variable_name]

# Displaying the array
print(array60)

# Accessing a variable from the dictionary
variable_name = "y_train_70"  # Example variable name
array70= y_train_arrays[variable_name]

# Displaying the array
print(array70)

# Accessing a variable from the dictionary
variable_name = "y_train_80"  # Example variable name
array80 = y_train_arrays[variable_name]

# Displaying the array
print(array80)

# Accessing a variable from the dictionary
variable_name = "y_train_90"  # Example variable name
array90 = y_train_arrays[variable_name]

# Displaying the array
print(array90)

# Accessing a variable from the dictionary
variable_name = "y_train_100"  # Example variable name
array100 = y_train_arrays[variable_name]

# Displaying the array
print(array100)
# Out:
# [13.87697818821428, 25.298072410990066, 28.016792823663845, 22.713957914250713, 10.592963161374113, 2.503480658031731]
# [13.042059071665905, 25.647428146541177, 28.17885114840155, 22.735603755402067, 10.751915222987549, 2.5004320219990914]
# [13.227883256334401, 25.36652021961211, 28.061869428054617, 22.72605602286854, 10.576899967334938, 2.535167014244901]
# [13.156767442584448, 26.13236858542916, 27.741610850717745, 22.7298496380458, 10.721470409170927, 2.5068477741321513]
# [13.560485644608587, 25.546182163495857, 27.902545055091807, 22.688515506979932, 10.559135512840792, 2.530145947616489]
# [13.853149809675335, 25.63581897089491, 28.185970320287705, 22.75026295137037, 10.56800639922856, 2.5193021778337985]
# [13.041666201322764, 25.763614269060852, 28.09322302969782, 22.744487421678166, 10.548279782531923, 2.4625199596972775]
# [12.796219852197655, 25.894561785853774, 28.04681602485357, 22.743029187632466, 10.681197680106614, 2.5074201300480206]
# ...

# %%
def create_GPR(COMenergy, Sfactor):
    
    COMenergy=np.array(COMenergy)
    Sfactor=np.array(Sfactor)
    
    X_train = COMenergy.reshape(-1, 1)

    y_train = Sfactor.reshape(-1, 1)

    n_samples = 6

    kernel = 1.0 * RBF(length_scale=1.0, length_scale_bounds=(1e-1, 10.0))
    gpr = GaussianProcessRegressor(kernel=kernel, random_state=0)

# %%
for array in new_arrays:
    create_GPR(trainingCOM, array)

# %%
def plot_gpr_samples(gpr_model, n_samples, ax):
    """Plot samples drawn from the Gaussian process model.

    If the Gaussian process model is not trained then the drawn samples are
    drawn from the prior distribution. Otherwise, the samples are drawn from
    the posterior distribution. Be aware that a sample here corresponds to a
    function.

    Parameters
    ----------
    gpr_model : `GaussianProcessRegressor`
        A :class:`~sklearn.gaussian_process.GaussianProcessRegressor` model.
    n_samples : int
        The number of samples to draw from the Gaussian process distribution.
    ax : matplotlib axis
        The matplotlib axis where to plot the samples.
    """
    
    #prediction data - make it the correct size and shape for the example 
    x = np.linspace(0, 0.2, 100)
    X = x.reshape(-1, 1)

    #calculate mean and std based off prediction data 
    y_mean, y_std = gpr_model.predict(X, return_std=True)
    
    y_samples = gpr_model.sample_y(X, n_samples)

    for idx, single_prior in enumerate(y_samples.T):
        ax.plot(
            x,
            single_prior,
            linestyle="--",
            alpha=0.7,
            label=f"Sampled function #{idx + 1}",
        )
    ax.plot(x, y_mean, color="black", label="Mean")
    ax.fill_between(
        x,
        y_mean - y_std,
        y_mean + y_std,
        alpha=0.2,
        color="black",
        label=r"$\pm$ 1 std. dev.",
    )
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    return x, y_mean

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF

# Assuming trainingCOM is your list of lists
X_train = np.array(trainingCOM).reshape(-1, 1)
y_train = np.array(array1).reshape(-1, 1)

n_samples = 6

kernel = 1.0 * RBF(length_scale=1.0, length_scale_bounds=(1e-1, 10.0))
gpr = GaussianProcessRegressor(kernel=kernel, random_state=0)

fig, axs = plt.subplots(nrows=2, sharex=True, sharey=False, figsize=(10, 8))

# plot prior
plot_gpr_samples(gpr, n_samples=n_samples, ax=axs[0])
axs[0].set_title("PDF sample 1")
axs[0].set_ylim([-3, 3])

# plot posterior
gpr.fit(X_train, y_train)
plot_gpr_samples(gpr, n_samples=n_samples, ax=axs[1])
axs[1].scatter(X_train[:, 0], y_train, color="red", zorder=100, label="Observations")
axs[1].legend(bbox_to_anchor=(1.05, 1.5), loc="upper left")
axs[1].set_title("PDF sample 1")
axs[1].set_ylim([0, 125])

fig.suptitle("Radial Basis Function kernel", fontsize=18)
plt.tight_layout()

# and optimizing the kernel
print(f"Kernel parameters before fit:\n{kernel})")
print(
    f"Kernel parameters after fit: \n{gpr.kernel_} \n"
    f"Log-likelihood: {gpr.log_marginal_likelihood(gpr.kernel_.theta):.3f}"
)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:455: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:445: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Kernel parameters before fit:
# 1**2 * RBF(length_scale=1))
# Kernel parameters after fit:
# 316**2 * RBF(length_scale=0.1)
# Log-likelihood: -109.534

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF

# Assuming trainingCOM is your list of lists
X_train = np.array(trainingCOM).reshape(-1, 1)
y_train = np.array(array10).reshape(-1, 1)

n_samples = 5

kernel = 1.0 * RBF(length_scale=1.0, length_scale_bounds=(1e-1, 10.0))
gpr = GaussianProcessRegressor(kernel=kernel, random_state=0)

fig, axs = plt.subplots(nrows=2, sharex=True, sharey=False, figsize=(10, 8))

# plot prior
plot_gpr_samples(gpr, n_samples=n_samples, ax=axs[0])
axs[0].set_title("Samples from prior distribution")
axs[0].set_ylim([-3, 3])

# plot posterior
gpr.fit(X_train, y_train)
plot_gpr_samples(gpr, n_samples=n_samples, ax=axs[1])
axs[1].scatter(X_train[:, 0], y_train, color="red", zorder=100, label="Observations")
axs[1].legend(bbox_to_anchor=(1.05, 1.5), loc="upper left")
axs[1].set_title("PDF sample 10")
axs[1].set_ylim([0, 125])

fig.suptitle("Radial Basis Function kernel", fontsize=18)
plt.tight_layout()

# and optimizing the kernel
print(f"Kernel parameters before fit:\n{kernel})")
print(
    f"Kernel parameters after fit: \n{gpr.kernel_} \n"
    f"Log-likelihood: {gpr.log_marginal_likelihood(gpr.kernel_.theta):.3f}"
)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:455: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:445: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Kernel parameters before fit:
# 1**2 * RBF(length_scale=1))
# Kernel parameters after fit:
# 316**2 * RBF(length_scale=0.1)
# Log-likelihood: -105.357

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF

# Assuming trainingCOM is your list of lists
X_train = np.array(trainingCOM).reshape(-1, 1)
y_train = np.array(array20).reshape(-1, 1)

n_samples = 5

kernel = 1.0 * RBF(length_scale=1.0, length_scale_bounds=(1e-1, 10.0))
gpr = GaussianProcessRegressor(kernel=kernel, random_state=0)

fig, axs = plt.subplots(nrows=2, sharex=True, sharey=False, figsize=(10, 8))

# plot prior
plot_gpr_samples(gpr, n_samples=n_samples, ax=axs[0])
axs[0].set_title("Samples from prior distribution")
axs[0].set_ylim([-3, 3])

# plot posterior
gpr.fit(X_train, y_train)
plot_gpr_samples(gpr, n_samples=n_samples, ax=axs[1])
axs[1].scatter(X_train[:, 0], y_train, color="red", zorder=100, label="Observations")
axs[1].legend(bbox_to_anchor=(1.05, 1.5), loc="upper left")
axs[1].set_title("PDF sample 20")
axs[1].set_ylim([0, 125])

fig.suptitle("Radial Basis Function kernel", fontsize=18)
plt.tight_layout()

# and optimizing the kernel
print(f"Kernel parameters before fit:\n{kernel})")
print(
    f"Kernel parameters after fit: \n{gpr.kernel_} \n"
    f"Log-likelihood: {gpr.log_marginal_likelihood(gpr.kernel_.theta):.3f}"
)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:455: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:445: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Kernel parameters before fit:
# 1**2 * RBF(length_scale=1))
# Kernel parameters after fit:
# 316**2 * RBF(length_scale=0.1)
# Log-likelihood: -107.116

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF

# Assuming trainingCOM is your list of lists
X_train = np.array(trainingCOM).reshape(-1, 1)
y_train = np.array(array30).reshape(-1, 1)

n_samples = 5

kernel = 1.0 * RBF(length_scale=1.0, length_scale_bounds=(1e-1, 10.0))
gpr = GaussianProcessRegressor(kernel=kernel, random_state=0)

fig, axs = plt.subplots(nrows=2, sharex=True, sharey=False, figsize=(10, 8))

# plot prior
plot_gpr_samples(gpr, n_samples=n_samples, ax=axs[0])
axs[0].set_title("Samples from prior distribution")
axs[0].set_ylim([-3, 3])

# plot posterior
gpr.fit(X_train, y_train)
plot_gpr_samples(gpr, n_samples=n_samples, ax=axs[1])
axs[1].scatter(X_train[:, 0], y_train, color="red", zorder=100, label="Observations")
axs[1].legend(bbox_to_anchor=(1.05, 1.5), loc="upper left")
axs[1].set_title("PDF sample 30")
axs[1].set_ylim([0, 125])

fig.suptitle("Radial Basis Function kernel", fontsize=18)
plt.tight_layout()

# and optimizing the kernel
print(f"Kernel parameters before fit:\n{kernel})")
print(
    f"Kernel parameters after fit: \n{gpr.kernel_} \n"
    f"Log-likelihood: {gpr.log_marginal_likelihood(gpr.kernel_.theta):.3f}"
)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:455: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:445: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Kernel parameters before fit:
# 1**2 * RBF(length_scale=1))
# Kernel parameters after fit:
# 316**2 * RBF(length_scale=0.1)
# Log-likelihood: -69.682

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF

# Assuming trainingCOM is your list of lists
X_train = np.array(trainingCOM).reshape(-1, 1)
y_train = np.array(array40).reshape(-1, 1)

n_samples = 5

kernel = 1.0 * RBF(length_scale=1.0, length_scale_bounds=(1e-1, 10.0))
gpr = GaussianProcessRegressor(kernel=kernel, random_state=0)

fig, axs = plt.subplots(nrows=2, sharex=True, sharey=False, figsize=(10, 8))

# plot prior
plot_gpr_samples(gpr, n_samples=n_samples, ax=axs[0])
axs[0].set_title("Samples from prior distribution")
axs[0].set_ylim([-3, 3])

# plot posterior
gpr.fit(X_train, y_train)
plot_gpr_samples(gpr, n_samples=n_samples, ax=axs[1])
axs[1].scatter(X_train[:, 0], y_train, color="red", zorder=100, label="Observations")
axs[1].legend(bbox_to_anchor=(1.05, 1.5), loc="upper left")
axs[1].set_title("PDF sample 40")
axs[1].set_ylim([0, 125])

fig.suptitle("Radial Basis Function kernel", fontsize=18)
plt.tight_layout()

# and optimizing the kernel
print(f"Kernel parameters before fit:\n{kernel})")
print(
    f"Kernel parameters after fit: \n{gpr.kernel_} \n"
    f"Log-likelihood: {gpr.log_marginal_likelihood(gpr.kernel_.theta):.3f}"
)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:455: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:445: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Kernel parameters before fit:
# 1**2 * RBF(length_scale=1))
# Kernel parameters after fit:
# 316**2 * RBF(length_scale=0.1)
# Log-likelihood: -94.913

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF

# Assuming trainingCOM is your list of lists
X_train = np.array(trainingCOM).reshape(-1, 1)
y_train = np.array(array50).reshape(-1, 1)

n_samples = 5

kernel = 1.0 * RBF(length_scale=1.0, length_scale_bounds=(1e-1, 10.0))
gpr = GaussianProcessRegressor(kernel=kernel, random_state=0)

fig, axs = plt.subplots(nrows=2, sharex=True, sharey=False, figsize=(10, 8))

# plot prior
plot_gpr_samples(gpr, n_samples=n_samples, ax=axs[0])
axs[0].set_title("Samples from prior distribution")
axs[0].set_ylim([-3, 3])

# plot posterior
gpr.fit(X_train, y_train)
plot_gpr_samples(gpr, n_samples=n_samples, ax=axs[1])
axs[1].scatter(X_train[:, 0], y_train, color="red", zorder=100, label="Observations")
axs[1].legend(bbox_to_anchor=(1.05, 1.5), loc="upper left")
axs[1].set_title("PDF sample 50")
axs[1].set_ylim([0, 125])

fig.suptitle("Radial Basis Function kernel", fontsize=18)
plt.tight_layout()

# and optimizing the kernel
print(f"Kernel parameters before fit:\n{kernel})")
print(
    f"Kernel parameters after fit: \n{gpr.kernel_} \n"
    f"Log-likelihood: {gpr.log_marginal_likelihood(gpr.kernel_.theta):.3f}"
)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:455: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:445: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Kernel parameters before fit:
# 1**2 * RBF(length_scale=1))
# Kernel parameters after fit:
# 316**2 * RBF(length_scale=0.1)
# Log-likelihood: -107.951

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF

# Assuming trainingCOM is your list of lists
X_train = np.array(trainingCOM).reshape(-1, 1)
y_train = np.array(array60).reshape(-1, 1)

n_samples = 5

kernel = 1.0 * RBF(length_scale=1.0, length_scale_bounds=(1e-1, 10.0))
gpr = GaussianProcessRegressor(kernel=kernel, random_state=0)

fig, axs = plt.subplots(nrows=2, sharex=True, sharey=False, figsize=(10, 8))

# plot prior
plot_gpr_samples(gpr, n_samples=n_samples, ax=axs[0])
axs[0].set_title("Samples from prior distribution")
axs[0].set_ylim([-3, 3])

# plot posterior
gpr.fit(X_train, y_train)
plot_gpr_samples(gpr, n_samples=n_samples, ax=axs[1])
axs[1].scatter(X_train[:, 0], y_train, color="red", zorder=100, label="Observations")
axs[1].legend(bbox_to_anchor=(1.05, 1.5), loc="upper left")
axs[1].set_title("PDF sample 60")
axs[1].set_ylim([0, 125])

fig.suptitle("Radial Basis Function kernel", fontsize=18)
plt.tight_layout()

# and optimizing the kernel
print(f"Kernel parameters before fit:\n{kernel})")
print(
    f"Kernel parameters after fit: \n{gpr.kernel_} \n"
    f"Log-likelihood: {gpr.log_marginal_likelihood(gpr.kernel_.theta):.3f}"
)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:455: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:445: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Kernel parameters before fit:
# 1**2 * RBF(length_scale=1))
# Kernel parameters after fit:
# 316**2 * RBF(length_scale=0.1)
# Log-likelihood: -95.699

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF

# Assuming trainingCOM is your list of lists
X_train = np.array(trainingCOM).reshape(-1, 1)
y_train = np.array(array70).reshape(-1, 1)

n_samples = 5

kernel = 1.0 * RBF(length_scale=1.0, length_scale_bounds=(1e-1, 10.0))
gpr = GaussianProcessRegressor(kernel=kernel, random_state=0)

fig, axs = plt.subplots(nrows=2, sharex=True, sharey=False, figsize=(10, 8))

# plot prior
plot_gpr_samples(gpr, n_samples=n_samples, ax=axs[0])
axs[0].set_title("Samples from prior distribution")
axs[0].set_ylim([-3, 3])

# plot posterior
gpr.fit(X_train, y_train)
plot_gpr_samples(gpr, n_samples=n_samples, ax=axs[1])
axs[1].scatter(X_train[:, 0], y_train, color="red", zorder=100, label="Observations")
axs[1].legend(bbox_to_anchor=(1.05, 1.5), loc="upper left")
axs[1].set_title("PDF sample 70")
axs[1].set_ylim([0, 125])

fig.suptitle("Radial Basis Function kernel", fontsize=18)
plt.tight_layout()

# and optimizing the kernel
print(f"Kernel parameters before fit:\n{kernel})")
print(
    f"Kernel parameters after fit: \n{gpr.kernel_} \n"
    f"Log-likelihood: {gpr.log_marginal_likelihood(gpr.kernel_.theta):.3f}"
)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:455: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:445: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Kernel parameters before fit:
# 1**2 * RBF(length_scale=1))
# Kernel parameters after fit:
# 316**2 * RBF(length_scale=0.1)
# Log-likelihood: -89.152

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF

# Assuming trainingCOM is your list of lists
X_train = np.array(trainingCOM).reshape(-1, 1)
y_train = np.array(array80).reshape(-1, 1)

n_samples = 5

kernel = 1.0 * RBF(length_scale=1.0, length_scale_bounds=(1e-1, 10.0))
gpr = GaussianProcessRegressor(kernel=kernel, random_state=0)

fig, axs = plt.subplots(nrows=2, sharex=True, sharey=False, figsize=(10, 8))

# plot prior
plot_gpr_samples(gpr, n_samples=n_samples, ax=axs[0])
axs[0].set_title("Samples from prior distribution")
axs[0].set_ylim([-3, 3])

# plot posterior
gpr.fit(X_train, y_train)
plot_gpr_samples(gpr, n_samples=n_samples, ax=axs[1])
axs[1].scatter(X_train[:, 0], y_train, color="red", zorder=100, label="Observations")
axs[1].legend(bbox_to_anchor=(1.05, 1.5), loc="upper left")
axs[1].set_title("PDF sample 80")
axs[1].set_ylim([0, 125])

fig.suptitle("Radial Basis Function kernel", fontsize=18)
plt.tight_layout()

# and optimizing the kernel
print(f"Kernel parameters before fit:\n{kernel})")
print(
    f"Kernel parameters after fit: \n{gpr.kernel_} \n"
    f"Log-likelihood: {gpr.log_marginal_likelihood(gpr.kernel_.theta):.3f}"
)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:455: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:445: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Kernel parameters before fit:
# 1**2 * RBF(length_scale=1))
# Kernel parameters after fit:
# 316**2 * RBF(length_scale=0.1)
# Log-likelihood: -115.722

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF

# Assuming trainingCOM is your list of lists
X_train = np.array(trainingCOM).reshape(-1, 1)
y_train = np.array(array90).reshape(-1, 1)

n_samples = 5

kernel = 1.0 * RBF(length_scale=1.0, length_scale_bounds=(1e-1, 10.0))
gpr = GaussianProcessRegressor(kernel=kernel, random_state=0)

fig, axs = plt.subplots(nrows=2, sharex=True, sharey=False, figsize=(10, 8))

# plot prior
plot_gpr_samples(gpr, n_samples=n_samples, ax=axs[0])
axs[0].set_title("Samples from prior distribution")
axs[0].set_ylim([-3, 3])

# plot posterior
gpr.fit(X_train, y_train)
plot_gpr_samples(gpr, n_samples=n_samples, ax=axs[1])
axs[1].scatter(X_train[:, 0], y_train, color="red", zorder=100, label="Observations")
axs[1].legend(bbox_to_anchor=(1.05, 1.5), loc="upper left")
axs[1].set_title("PDF sample 90")
axs[1].set_ylim([0, 125])

fig.suptitle("Radial Basis Function kernel", fontsize=18)
plt.tight_layout()

# and optimizing the kernel
print(f"Kernel parameters before fit:\n{kernel})")
print(
    f"Kernel parameters after fit: \n{gpr.kernel_} \n"
    f"Log-likelihood: {gpr.log_marginal_likelihood(gpr.kernel_.theta):.3f}"
)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:455: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:445: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Kernel parameters before fit:
# 1**2 * RBF(length_scale=1))
# Kernel parameters after fit:
# 316**2 * RBF(length_scale=0.1)
# Log-likelihood: -62.651

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF

# Assuming trainingCOM is your list of lists
X_train = np.array(trainingCOM).reshape(-1, 1)
y_train = np.array(array100).reshape(-1, 1)

n_samples = 5

kernel = 1.0 * RBF(length_scale=1.0, length_scale_bounds=(1e-1, 10.0))
gpr = GaussianProcessRegressor(kernel=kernel, random_state=0)

fig, axs = plt.subplots(nrows=2, sharex=True, sharey=False, figsize=(10, 8))

# plot prior
plot_gpr_samples(gpr, n_samples=n_samples, ax=axs[0])
axs[0].set_title("Samples from prior distribution")
axs[0].set_ylim([-3, 3])

# plot posterior
gpr.fit(X_train, y_train)
plot_gpr_samples(gpr, n_samples=n_samples, ax=axs[1])
axs[1].scatter(X_train[:, 0], y_train, color="red", zorder=100, label="Observations")
axs[1].legend(bbox_to_anchor=(1.05, 1.5), loc="upper left")
axs[1].set_title("PDF sample 100")
axs[1].set_ylim([0, 125])

fig.suptitle("Radial Basis Function kernel", fontsize=18)
plt.tight_layout()

# and optimizing the kernel
print(f"Kernel parameters before fit:\n{kernel})")
print(
    f"Kernel parameters after fit: \n{gpr.kernel_} \n"
    f"Log-likelihood: {gpr.log_marginal_likelihood(gpr.kernel_.theta):.3f}"
)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:455: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:445: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Kernel parameters before fit:
# 1**2 * RBF(length_scale=1))
# Kernel parameters after fit:
# 316**2 * RBF(length_scale=0.1)
# Log-likelihood: -99.424
